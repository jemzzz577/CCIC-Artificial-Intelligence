# %%
import pandas as pd
import requests
import time
import random

# %%
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMWE0MmQ2NmUwZGY3NDA2OTVkMzgyN2NkMTY4NzBlYiIsIm5iZiI6MTc2MjE4NzcwMi4wNzUsInN1YiI6IjY5MDhkOWI2YzMwYTQ5NzI3YjQ2NDM1OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.hbsrKASSnE0lKSkxLJsJR5_OPi1fIlmo-O09sIqZsXk",
    "accept": "application/json"
}

# %%
count = 0
while count < 1000:
    movie_id = str(random.randint(0, 2000000))
    endpoint = "https://api.themoviedb.org/3/movie/" + movie_id
    response = requests.get(endpoint, headers=headers)
    print(response)
    count = count + 1

# %%
response

# %%
movie_id

# %%
json_response = response.json()

# %%
json_response

# %%
genres = json_response['genres']

# %%
genres

# %%
raw_df = {
    "Title": "",
    "Runtime": 0,
    "Popularity": 0,
    "Genres": [genres]
}

# %%
df = pd.DataFrame(raw_df)
df.head()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

movies_df = pd.DataFrame(raw_df)

n_trials = 1000
sample_size = 10

mean_popularities = [
    movies_df['Popularity'].sample(sample_size, replace=True).mean()
    for _ in range(n_trials)
]

sns.histplot(mean_popularities, bins=30, kde=True)
plt.title('Distribution of Mean Popularity Scores (1000 trials, n=10)')
plt.xlabel('Mean Popularity')
plt.ylabel('Frequency')
plt.show()

# %%
#something about this is telling me this isnt accurate

# %%
movies_df = pd.DataFrame(raw_df)

n_trials = 1000
sample_size = 100

mean_popularities = [
    movies_df['Popularity'].sample(sample_size, replace=True).mean()
    for _ in range(n_trials)
]

sns.histplot(mean_popularities, bins=30, kde=True)
plt.title('Distribution of Mean Popularity Scores (1000 trials, n=100)')
plt.xlabel('Mean Popularity')
plt.ylabel('Frequency')
plt.show()

# %%
# they look the same i dont like this

# %%
UNFINISHED AND BUGGY
