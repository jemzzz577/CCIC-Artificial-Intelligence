# %% [markdown]
# # How many Yelp reviews does Burger King have compared to Google reviews?

# %% [markdown]
# I plan to conduct an observational study. I also plan to use a sample and hopefully find what I am looking for. I will try to find sources to help answer my question. This will be a retrospective study because the data has already been created.

# %% [markdown]
# # How I collected my data:

# %% [markdown]
# I originally was going to use Kaggle and Google Datasets but they just weren't working at all. The data didn't exist on Kaggle and Google Datasets wouldn't let me in. So, I resorted to using ChatGPT, my best friend. Yes, ChatGPT collected the data for me. There may be some biases within my data, but I believe it is mostly accurate. Maybe the number of ratings may not be too accurate, but like I said, I believe it is more accurate than otherwise.

# %%
import pandas as pd
import seaborn as sns

# %%
burgerking = pd.read_csv("Burger King.csv")

# %%
burgerking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        8 non-null      object
#  1   Yelp_Reviews    8 non-null      int64
#  2   Yelp_Rating     8 non-null      float64
#  3   Google_Reviews  8 non-null      int64
#  4   Google_Rating   8 non-null      float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 448.0+ bytes

# %%
df.astype(float)
# Out:
#    Yelp_Rating  Yelp_Reviews
# 0         12.0          10.0
# 1         24.0          20.0
# 2         33.0          30.0
# 3         47.0          40.0
# 4         58.0          50.0

# %%
sns.scatterplot(data=burgerking, x="Yelp_Reviews", y="Google_Reviews")
# Out:
# <Axes: xlabel='Yelp_Reviews', ylabel='Google_Reviews'>

# %%
sns.lineplot(data=burgerking, x="Google_Reviews", y="Yelp_Reviews")
sns.scatterplot(data=burgerking, x="Google_Reviews", y="Yelp_Reviews")
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Google_Reviews', ylabel='Yelp_Reviews'>

# %%
r = burgerking['Yelp_Reviews'].corr(burgerking['Google_Reviews'])

# %%
sns.scatterplot(data=burgerking, x="Yelp_Reviews", y="Google_Reviews")
# Out:
# <Axes: xlabel='Yelp_Reviews', ylabel='Google_Reviews'>

# %%
sns.lineplot(data=burgerking, x="Yelp_Reviews", y="Google_Reviews")
sns.scatterplot(data=burgerking, x="Yelp_Reviews", y="Google_Reviews")
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Yelp_Reviews', ylabel='Google_Reviews'>

# %%
r = burgerking['Google_Reviews'].corr(df['Yelp_Reviews'])
print("Correlation coefficient (r):", r)
# Out:
# Correlation coefficient (r): -0.17641057126819928
