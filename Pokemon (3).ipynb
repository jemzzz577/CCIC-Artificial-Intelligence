# %% [markdown]
# QUESTION

# %% [markdown]
# What is the highest speed in Pokemon besides Pikachu?

# %% [markdown]
# HOW WILL I ANSWER THIS?

# %% [markdown]
# I plan to use to use actual data for answering my question like graphs, bar charts, or anything else really. This is going to be an observational study. I want to examine the population and see what the highest speed is.

# %%
import pandas as pd
import seaborn as sns

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon.columns
# Out:
# Index(['name', 'pokedex_number', 'abilities', 'attack', 'capture_rate',
#        'classfication', 'defense', 'height_m', 'hp', 'sp_attack', 'sp_defense',
#        'speed', 'type1', 'type2', 'weight_kg', 'generation', 'is_legendary'],
#       dtype='object')

# %%
pikachu = pokemon[pokemon['name'] == "Pikachu"]

# %%
sns.histplot(data=pokemon, x="speed")
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='speed', ylabel='Count'>

# %%
pokemon["speed"].mean()
# Out:
# 66.33458177278402

# %%
data = pokemon["speed"]

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

print("IQR:", IQR)
# Out:
# IQR: 40.0

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data=pokemon, x="speed")
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='speed', ylabel='Density'>

# %% [markdown]
# The peak is about 60% speed and 0.012 density.

# %%
def percentile(data, variable, target):
    n = len(data.[variable])
    more_than_data = data[data.variable] <= target
    print(more_than_data)
    return more_than_data/n
# Out:
#   Cell In[70], line 2
#     n = len(data.[variable])
#                  ^
# SyntaxError: invalid syntax
